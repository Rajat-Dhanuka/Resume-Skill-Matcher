# %% [markdown]
# Dataset link - https://github.com/florex/resume_corpus

# %%
import os
import pandas as pd
import numpy as np
import unicodedata
import re
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
file_path = r'C:\Coding\Jupyter notebooks\resume_corpus-master\resume_samples\resume_samples.txt'

with open(file_path, 'r', encoding='latin1') as file:
    lines = file.readlines()

# Initialize empty lists to store data and line numbers where the if condition is not met
ids = []
occupations = []
resumes = []
problematic_lines = []

# Process each line and extract the data
for line_number, line in enumerate(lines, 1):  # Start line_number from 1
    parts = line.strip().split(':::')
    if len(parts) == 3:
        ids.append(parts[0])
        occupations.append(parts[1])
        resumes.append(parts[2])
    else:
        problematic_lines.append(line_number)

# Create the DataFrame
resume_data = pd.DataFrame({'ID': ids, 'Occupations': occupations, 'Resume': resumes})

# Print the line numbers where the if condition is not met
print("Problematic lines:", problematic_lines)

# Convert the line numbers to list indices (subtract 1)
problematic_indices = [line_number - 1 for line_number in problematic_lines]
# Out:
# Problematic lines: [4278, 21416, 25427]

# %%
resume_data.head()
# Out:
#                                                   ID  \
# 0  C:\Workspace\java\scrape_indeed\dba_part_1\1.h...
# 1  C:\Workspace\java\scrape_indeed\dba_part_1\10....
# 2  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 3  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 4  C:\Workspace\java\scrape_indeed\dba_part_1\100...
#
#                                          Occupations  \
# 0  Database Administrator;Database Administrator;...
# 1  Database Administrator;SQL, Microsoft PowerPoi...
# 2  Oracle Database Administrator;Oracle Database ...
# 3  Amazon Redshift Administrator and ETL Develope...
# 4  Scrum Master;Oracle Database Administrator/ Sc...
#
#                                               Resume
# 0  Database Administrator <span class="hl">Databa...
# 1  Database Administrator <span class="hl">Databa...
# 2  Oracle Database Administrator Oracle <span cla...
# 3  Amazon Redshift Administrator and ETL Develope...
# 4  Scrum Master Scrum Master Scrum Master Richmon...

# %%
# Directory path of the resumes_corpus folder containing .lab files
lab_folder_path = 'C:/Coding/Jupyter notebooks/resume_corpus-master/resumes_corpus/'

# List all the .lab files in the resumes_corpus folder
lab_files = [file for file in os.listdir(lab_folder_path) if file.endswith('.lab')]

# Initialize an empty list to store the extracted labels
labels_list = []

# Read each .lab file and extract the labels
for lab_file in lab_files:
    with open(os.path.join(lab_folder_path, lab_file), 'r') as file:
        labels = file.read().strip()
        labels_list.append(labels)

# Remove the labels for problematic resume data using the indices
labels_list = [labels_list[i] for i in range(len(labels_list)) if i not in problematic_indices]        

# Merge the extracted labels with the existing dataframe
resume_data['Labels'] = labels_list

resume_data.head()
# Out:
#                                                   ID  \
# 0  C:\Workspace\java\scrape_indeed\dba_part_1\1.h...
# 1  C:\Workspace\java\scrape_indeed\dba_part_1\10....
# 2  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 3  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 4  C:\Workspace\java\scrape_indeed\dba_part_1\100...
#
#                                          Occupations  \
# 0  Database Administrator;Database Administrator;...
# 1  Database Administrator;SQL, Microsoft PowerPoi...
# 2  Oracle Database Administrator;Oracle Database ...
# 3  Amazon Redshift Administrator and ETL Develope...
# 4  Scrum Master;Oracle Database Administrator/ Sc...
#
#                                               Resume                  Labels
# 0  Database Administrator <span class="hl">Databa...  Database_Administrator
# 1  Database Administrator <span class="hl">Databa...  Database_Administrator
# 2  Oracle Database Administrator Oracle <span cla...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator

# %%
def preprocess_normalized_classes(file_path):
    normalized_mapping = {}
    with open(file_path, 'r', encoding='latin-1') as file:
        for line in file:
            line = line.strip()
            # Use regular expressions to find original occupations and normalized occupation
            #regex is used because the data is inconsistently seperated by ":" and " : "
            match = re.match(r'(.+?)\s*:\s*(.+)', line)
            if match:
                original_occupations, normalized_occupation = match.groups()
                #this is done to handle inconsistency in use seperators for original occupation like "/", "\", "\x95" 
                original_occupations = [occ.strip().replace('\x95', '').lower() for occ in re.split(r'[\\\/\x95]', original_occupations)]
                normalized_occupation = normalized_occupation.strip()

                for original_occ in original_occupations:
                    normalized_mapping[original_occ] = normalized_occupation
                    
    #df = pd.DataFrame(list(normalized_mapping.items()), columns=['Original_Occupation', 'Normalized_Occupation'])
    return normalized_mapping


normal_path = 'C:/Coding/Jupyter notebooks/resume_corpus-master/normlized_classes.txt'
normalised_mapping = preprocess_normalized_classes(normal_path)
normalised_mapping
# Out:
# {'front end developer (branding specialist)': 'Front_End_Developer',
#  'mis network analyst': 'Network_Administrator',
#  'designer & front- end developer': 'Front_End_Developer',
#  'network administrator politécnico 5 septiembre': 'Network_Administrator',
#  'web developer': 'Database_Administrator,Web_Developer',
#  '.net developer': 'Web_Developer',
#  'senior project manager - united launch alliance (ula)': 'Project_manager',
#  'product manager': 'Systems_Administrator',
#  'project manager': 'Project_manager',
#  'network': 'Systems_Administrator,Network_Administrator',
#  'firewall engineer': 'Network_Administrator,Security_Analyst',
#  'web producer': 'Web_Developer,Front_End_Developer',
#  'database specialist & compliancewire administrator': 'Database_Administrator',
#  'manager of it infrastructure and operations': 'Project_manager',
#  'security analyst': 'Security_Analyst',
#  'software engineer': 'Software_Developer',
#  'systems analyst': 'Project_manager',
#  'oracle production dba': 'Database_Administrator',
#  'software developer': 'Software_Developer',
#  'linux server administrator': 'Software_Developer',
#  'network administrator': 'Systems_Administrator,Network_Administrator',
#  'i.t': 'Web_Developer',
#  'database administrator': 'Database_Administrator,Web_Developer',
#  'finance specialist ii': 'Database_Administrator',
#  'manager, program management': 'Project_manager',
#  'internal contractor': 'Front_End_Developer',
#  'front- end developer': 'Front_End_Developer',
#  'research programmer': 'Front_End_Developer',
#  'analyst i': 'Front_End_Developer',
#  'senior web developer and crm developer': 'Web_Developer',
#  'receptionist': 'Database_Administrator',
#  'python full stack developer': 'Python_Developer',
#  'cyber security': 'Security_Analyst',
#  'it network & infrastructure project coordinator (contractor)': 'Project_manager',
#  'project manager, business development': 'Project_manager',
#  'lead sql server database administrator': 'Database_Administrator',
#  'it project manager consultant': 'Project_manager',
#  'i.t. network': 'Systems_Administrator,Project_manager,Network_Administrator',
#  'systems administrator': 'Systems_Administrator',
#  'senior information security officer within the wholesale business security office': 'Security_Analyst',
#  'web designer': 'Project_manager',
#  'front end developer': 'Front_End_Developer',
#  'seo assistant': 'Web_Developer,Project_manager,Front_End_Developer',
#  'it manager, six sigma opx': 'Project_manager',
#  'java developer for pharmacy management system project, draw er': 'Java_Developer',
#  'it manager (hands-on)': 'Project_manager',
#  'telecommunications administrator': 'Project_manager',
#  'senior it project manager, (contract': 'Project_manager',
#  'sr database administrator': 'Database_Administrator',
#  'contract technical project manager (iepm)': 'Project_manager',
#  'network support administrator ii': 'Network_Administrator',
#  'contract java & python developer': 'Java_Developer,Python_Developer',
#  'program manager (contractor)': 'Project_manager',
#  'analyst, consultant, network': 'Database_Administrator,Network_Administrator',
#  'sharepoint systems administrator': 'Systems_Administrator',
#  'developer': 'Web_Developer',
#  'program manager - engineering security': 'Project_manager',
#  'system and networking engineer - information technology': 'Systems_Administrator',
#  'full stack developer (angular4&7': 'Web_Developer',
#  'web api)': 'Web_Developer',
#  'tier 1 &2 network engineer': 'Network_Administrator',
#  'associate database': 'Database_Administrator,Systems_Administrator',
#  'maintenance software engineer': 'Software_Developer',
#  'global it services - technical project manager': 'Project_manager,Network_Administrator',
#  'network and systems analyst': 'Project_manager,Network_Administrator',
#  'entity framework (2 years)': 'Web_Developer',
#  'project manager - it-telecom': 'Project_manager',
#  'it project coordinator': 'Project_manager',
#  'content specialist': 'Web_Developer,Front_End_Developer',
#  'python scripts developer': 'Python_Developer',
#  '(contractor) it project manager': 'Project_manager',
#  'enterprise database architect - database administrator': 'Database_Administrator',
#  'software implementations expert': 'Software_Developer',
#  'system administrator, network': 'Systems_Administrator,Network_Administrator',
#  'systems engineer': 'Systems_Administrator',
#  'sr. front- end': 'Front_End_Developer',
#  'ui developer': 'Front_End_Developer',
#  'systems engineer -third party integrations': 'Systems_Administrator',
#  'lead backend developer': 'Python_Developer,Software_Developer',
#  'sysadmin': 'Systems_Administrator',
#  'sr. web developer': 'Web_Developer',
#  'project development manager': 'Web_Developer,Project_manager',
#  'database migration engineer to aws cloud': 'Database_Administrator',
#  'it security analyst (access and authentication)': 'Security_Analyst',
#  'senior it security compliance specialist, rga': 'Security_Analyst',
#  'solution architect': 'Project_manager',
#  'deputy project manager': 'Project_manager',
#  'sr. ui designer and application developer': 'Software_Developer,Front_End_Developer',
#  'nsw systems engineer': 'Systems_Administrator',
#  'sr oracle database administrator': 'Database_Administrator',
#  'web & software developer, it specialist': 'Web_Developer,Software_Developer',
#  'technical project manager-contractor': 'Project_manager',
#  'information assurance officer': 'Systems_Administrator',
#  'cyber security liaison': 'Security_Analyst',
#  'mid-level network engineer': 'Network_Administrator',
#  'it leadership intern ( project manager': 'Project_manager',
#  'business analyst)': 'Project_manager',
#  'project manager & full-cycle software developer': 'Software_Developer,Project_manager',
#  'sr. java': 'Java_Developer',
#  'j2ee full stack developer': 'Java_Developer,Web_Developer',
#  'sr. engineer': 'Python_Developer',
#  'work as a project supervisor and design manager': 'Project_manager',
#  'database analyst & django': 'Database_Administrator,Web_Developer,Python_Developer,Software_Developer',
#  'python developer, it division': 'Web_Developer,Python_Developer,Software_Developer',
#  'sr. full stack python developer': 'Python_Developer',
#  'multimedia, web developer internship': 'Web_Developer',
#  'security analyst remarkable technology': 'Security_Analyst',
#  'business manager - it': 'Project_manager',
#  'java': 'Java_Developer,Web_Developer',
#  'sfcc developer': 'Java_Developer',
#  'programmer iv': 'Security_Analyst',
#  'cyber security analyst': 'Security_Analyst',
#  'ui': 'Web_Developer,Front_End_Developer',
#  'front end web developer': 'Web_Developer,Front_End_Developer',
#  'software development life cycle (5 years)': 'Software_Developer',
#  'python': 'Java_Developer,Web_Developer,Python_Developer',
#  'legacy application developer': 'Python_Developer,Software_Developer',
#  'microsoft software engineer': 'Software_Developer',
#  'c': 'Python_Developer',
#  'c++and python developer': 'Python_Developer',
#  'part-time senior developer and system administrator': 'Systems_Administrator',
#  'java web application developer intern': 'Java_Developer,Web_Developer,Software_Developer',
#  'reporting analyst': 'Database_Administrator',
#  'jr. java developer intern': 'Java_Developer',
#  'it development manager': 'Project_manager',
#  'web hosting specialist and website developer': 'Web_Developer',
#  "system administrator sun sparcstation's": 'Systems_Administrator',
#  'director, software development, iot': 'Software_Developer',
#  'web content editor & front-end developer': 'Web_Developer,Front_End_Developer',
#  'network engineer': 'Network_Administrator',
#  'support': 'Systems_Administrator',
#  'peoplesoft database administrator': 'Database_Administrator',
#  'jr network administrator': 'Systems_Administrator,Network_Administrator',
#  'java endur developer': 'Java_Developer',
#  'sr. it project': 'Project_manager',
#  'applications manager': 'Project_manager',
#  'data analyst': 'Web_Developer,Front_End_Developer',
#  'python developer': 'Python_Developer',
#  'member of kaohsiung software development group': 'Software_Developer',
#  'consultant sr. system architect': 'Project_manager',
#  'sdlc project manager': 'Project_manager',
#  'python, perl developer, servicenow': 'Python_Developer',
#  'ios application developer - software engineer': 'Software_Developer',
#  'it consultant software': 'Web_Developer,Software_Developer',
#  'mobile & web developer': 'Web_Developer,Software_Developer',
#  'software mgr., sr. sw developer (c++, c, assembler)': 'Software_Developer',
#  'informatica': 'Database_Administrator',
#  'database developer': 'Database_Administrator',
#  'senior it project manager': 'Project_manager',
#  'senior business systems analyst': 'Project_manager',
#  'chief software architect': 'Software_Developer',
#  'it sales manager': 'Project_manager',
#  'program manager': 'Project_manager',
#  'senior project manager': 'Project_manager',
#  'cultivate agile, program': 'Project_manager',
#  'project manager & agile coach': 'Project_manager',
#  'it supervisor': 'Project_manager,Network_Administrator,Security_Analyst',
#  'curriculum manager': 'Project_manager',
#  'senior security consultant': 'Security_Analyst',
#  'front end developer manager': 'Front_End_Developer',
#  'senior java developer': 'Java_Developer',
#  'angular js': 'Java_Developer',
#  'business analyst': 'Project_manager',
#  'project manager it- billing operations (contractor': 'Project_manager',
#  'junior web developer - angular': 'Web_Developer',
#  'sr. database administrator': 'Database_Administrator',
#  'team lead': 'Security_Analyst',
#  'director of it': 'Project_manager',
#  'front-end web development, web design, adobe sitecatalyst, adobe test&target, page speed optimization, apache solr, ppc online advertising': 'Front_End_Developer',
#  'telecom analyst': 'Network_Administrator',
#  'dba (1 year)': 'Database_Administrator',
#  'director of it governance, risk & compliance and audit services': 'Project_manager',
#  'network manager': 'Network_Administrator',
#  'engineer': 'Systems_Administrator',
#  'system programmer': 'Database_Administrator,Systems_Administrator',
#  'administrator': 'Systems_Administrator',
#  'project leader software engineer': 'Software_Developer',
#  'database administrator lead': 'Database_Administrator',
#  'senior database administrator': 'Database_Administrator',
#  'web administrator. parsons': 'Database_Administrator',
#  'database administrator & administrative assistant': 'Database_Administrator',
#  'j2ee': 'Java_Developer,Web_Developer',
#  'digital designer': 'Python_Developer',
#  'python, selenium webdriver, sql, javascript, flask, jquery, http, html, css': 'Python_Developer',
#  'consultant': 'Software_Developer',
#  'freelance web developer': 'Web_Developer',
#  'network consulting engineer': 'Network_Administrator',
#  'python, django 1.4, ruby, html5, css, xml, mysql, javascript, eclipse, git, github, aws, linux, shell scripting, jira, jenkins, docker, angularjs, (5 years)': 'Python_Developer',
#  'project manager - business intelligence & clinical product development': 'Project_manager',
#  'e-labs global project manager': 'Project_manager',
#  'backend java developer': 'Java_Developer,Software_Developer',
#  'summer python developer': 'Python_Developer',
#  'remote - lead software engineer in front end': 'Software_Developer',
#  'security+ certified cloud engineer, network engineer': 'Network_Administrator',
#  'python web developer': 'Web_Developer,Python_Developer',
#  'web design, web development, graphic design, video editing, application development, html5, css3, javascript accessibility, browser compatibility testing, mobile first responsive design, progressive enhancement techniques, wireframing, ui design, jquery, twitter bootstrap 3, foundation 5, haml, slim, less, sass, compass, coffeescript, php, mysql, ruby on rails, git, subversion, wordpress, shopify, photoshop, illustrator, fireworks, mockups, apple final cut pro x, adobe premiere, visual basic, c#, operating systems linux, mac os x, windows': 'Web_Developer,Software_Developer',
#  'network admin': 'Network_Administrator',
#  'system admin': 'Systems_Administrator',
#  'system admin (less than 1 year)': 'Systems_Administrator',
#  'aviation security analyst': 'Security_Analyst',
#  'level 2 generalist, level 2 operating systems engineer': 'Systems_Administrator',
#  'it security applications specialist': 'Security_Analyst',
#  'ux': 'Front_End_Developer',
#  'ui front end developer': 'Front_End_Developer',
#  'video teleconference and network administrator': 'Network_Administrator',
#  'programmer': 'Web_Developer',
#  'database analyst': 'Database_Administrator',
#  'senior manager, global it operations': 'Project_manager',
#  'it security risk manager': 'Project_manager,Security_Analyst',
#  'senior it analyst and it manager': 'Project_manager',
#  'software analyst': 'Software_Developer',
#  'enterprise it security specialist': 'Network_Administrator,Security_Analyst',
#  'senior network security analyst': 'Network_Administrator,Security_Analyst',
#  'software engineer, application development team': 'Software_Developer',
#  'it project manager | network engineer': 'Project_manager,Network_Administrator',
#  'program manager and content developer': 'Project_manager',
#  'microsoft office microsoft office suite, google docs microsoft project waterfall': 'Software_Developer',
#  'agile methodology agile development rally agile software project scheduling strategic planning verbal and written communication leadership negotiation team management risk management cross-team integration sql': 'Software_Developer',
#  'accountant': 'Security_Analyst',
#  'j2ee java developer': 'Java_Developer,Web_Developer',
#  'systems consultant': 'Project_manager',
#  'project manager (consultant)': 'Project_manager',
#  'front- end web developer and freelance writer': 'Web_Developer,Front_End_Developer',
#  'consultant flexcube core banking': 'Database_Administrator',
#  'consultant - it security operations': 'Security_Analyst',
#  'freelance web developer (off-site)': 'Web_Developer',
#  'exchange': 'Systems_Administrator',
#  'software developer in c# .net': 'Web_Developer,Software_Developer',
#  'director - it security & technical services': 'Project_manager',
#  'web developer - consultant': 'Web_Developer',
#  'system administrator': 'Systems_Administrator',
#  'senior prepress': 'Systems_Administrator,Project_manager',
#  '.net developer ii': 'Web_Developer',
#  'a-c electric, software developer intern': 'Software_Developer',
#  'senior network': 'Systems_Administrator',
#  'data center engineer': 'Network_Administrator',
#  'senior project': 'Project_manager',
#  'i.t. manager': 'Systems_Administrator,Project_manager',
#  'systems administrator south county': 'Systems_Administrator,Project_manager',
#  'information analyst': 'Project_manager',
#  'it security analyst - part time': 'Security_Analyst',
#  'freelance graphic designer': 'Web_Developer',
#  'application development (8 years)': 'Software_Developer',
#  'r&d software engineer': 'Software_Developer',
#  'lead software': 'Software_Developer,Systems_Administrator,Security_Analyst',
#  'systems analyst and security engineer': 'Software_Developer,Systems_Administrator,Security_Analyst',
#  'contingent worker': 'Software_Developer',
#  'system & network administrator': 'Systems_Administrator,Network_Administrator',
#  'application engineer': 'Software_Developer',
#  'project manager & software developer, intern': 'Software_Developer,Project_manager',
#  'it business consultant & network engineer': 'Network_Administrator',
#  'it specialist (information systems security officer)': 'Systems_Administrator,Security_Analyst',
#  'network designer': 'Project_manager',
#  'sr. systems': 'Systems_Administrator,Network_Administrator',
#  'it project manager': 'Software_Developer,Project_manager',
#  'technician': 'Systems_Administrator',
#  'application analyst java': 'Java_Developer',
#  'consultant, it project manager': 'Project_manager',
#  'marist web services - student web developer': 'Web_Developer',
#  'it infrastructure program manager': 'Project_manager',
#  'java developer & ui developer': 'Java_Developer,Front_End_Developer',
#  'security program manager': 'Project_manager',
#  'network engineer ii': 'Network_Administrator',
#  'assurance manager': 'Network_Administrator',
#  'manager, application development': 'Software_Developer',
#  'aws engineer': 'Python_Developer',
#  'it auditor': 'Security_Analyst',
#  'iphone application developer-intern': 'Software_Developer',
#  'front end': 'Web_Developer,Front_End_Developer',
#  'web': 'Software_Developer,Front_End_Developer',
#  'graphic design': 'Web_Developer',
#  'designer': 'Web_Developer,Software_Developer',
#  'social media intern': 'Web_Developer',
#  'security analyst 2': 'Security_Analyst',
#  'business analyst - security administrator': 'Security_Analyst',
#  'sr. security consultant': 'Security_Analyst',
#  'it project manager, professional services': 'Project_manager',
#  'it technical specialist': 'Web_Developer,Software_Developer',
#  'it manager': 'Web_Developer,Software_Developer,Project_manager',
#  'security administrator': 'Network_Administrator',
#  'threat and vulnerability management - it security analyst': 'Security_Analyst',
#  'identity & access management': 'Security_Analyst',
#  'global security analyst': 'Security_Analyst',
#  'security analyst i': 'Security_Analyst',
#  'senior oracle dba': 'Database_Administrator',
#  'database services manager': 'Database_Administrator',
#  'iv and v project manager asr tech solutions': 'Project_manager',
#  'senior help desk': 'Systems_Administrator',
#  'oracle dba (6 years)': 'Database_Administrator',
#  'entity framework 6 (2 years)': 'Web_Developer',
#  'application security engineer': 'Software_Developer,Security_Analyst',
#  'web application penetration tester': 'Web_Developer,Software_Developer,Security_Analyst',
#  'programmer, database administrator': 'Database_Administrator',
#  'angular front- end developer': 'Front_End_Developer',
#  'junior database developer': 'Database_Administrator',
#  'senior ui': 'Web_Developer,Software_Developer,Front_End_Developer',
#  'senior it security analyst, professional services': 'Security_Analyst',
#  'front end wordpress developer | graphic designer': 'Front_End_Developer',
#  'database programming': 'Database_Administrator',
#  'admin': 'Systems_Administrator',
#  'software design': 'Database_Administrator',
#  'sale support': 'Database_Administrator',
#  'worley - it pmo project manager - americas (consultant)': 'Project_manager',
#  'sr. san admin': 'Project_manager',
#  'tactical systems program manager': 'Project_manager',
#  'network administrator for marine corps (4 years)': 'Network_Administrator',
#  'senior sql server dba': 'Database_Administrator',
#  'python developer training': 'Python_Developer',
#  'freelancer, online, worldwide - android developer, python': 'Python_Developer',
#  'mts 1, software engineer': 'Software_Developer',
#  'ecommerce': 'Project_manager',
#  'front- end web developer': 'Web_Developer,Front_End_Developer',
#  'email marketing': 'Web_Developer,Front_End_Developer',
#  'registrar': 'Database_Administrator',
#  'corporate database developer': 'Database_Administrator',
#  'manager': 'Project_manager',
#  'database developer iii': 'Database_Administrator',
#  'web administrator': 'Web_Developer',
#  'senior oracle applications dba': 'Database_Administrator',
#  'networking instructor': 'Systems_Administrator',
#  'custom web developer': 'Web_Developer',
#  'compliance and security analyst': 'Security_Analyst',
#  'software developer apprentice': 'Software_Developer',
#  'mobile': 'Web_Developer',
#  'web app developer': 'Web_Developer',
#  'lead developer for the web application': 'Web_Developer,Software_Developer',
#  'systems administrator (fulltime)': 'Systems_Administrator',
#  'facility technician and database administrator': 'Database_Administrator',
#  'senior software developer, r&d': 'Software_Developer',
#  'senior developer in the software': 'Software_Developer',
#  'application support': 'Systems_Administrator',
#  'network support analyst': 'Network_Administrator',
#  'senior it project manager, security, application development': 'Software_Developer,Project_manager,Security_Analyst',
#  'intermediate cyber security specialist': 'Security_Analyst',
#  'senior software developer (remote)': 'Software_Developer',
#  'ui developer (spring intern)': 'Front_End_Developer',
#  'it project manager - post merger integration': 'Project_manager',
#  'project manager it support': 'Project_manager',
#  'it consultant - python developer': 'Python_Developer,Software_Developer',
#  'data engineer': 'Python_Developer',
#  'web developer (part-time, freelance)': 'Web_Developer',
#  'designer and front- end developer': 'Front_End_Developer',
#  'it software engineer': 'Software_Developer',
#  'sr full stack web developer': 'Web_Developer',
#  'java script developer': 'Java_Developer',
#  'in network engineer (voice)': 'Network_Administrator',
#  'information systems security officer (contractor)': 'Security_Analyst',
#  'ux designer': 'Web_Developer',
#  'database administrator for siterra program': 'Database_Administrator',
#  'manager - network information security officer (niso) (full-time)': 'Security_Analyst',
#  'application architect': 'Software_Developer',
#  'project leader': 'Project_manager',
#  'sr. consultant': 'Project_manager',
#  'sr. software developer': 'Software_Developer',
#  'ios-android developer': 'Web_Developer,Python_Developer',
#  'javascript- python developer': 'Web_Developer,Python_Developer',
#  'senior graphic designer & web developer': 'Web_Developer',
#  'vice president - chief information security officer (ciso) of americas (full-time)': 'Security_Analyst',
#  'sap basis and security consultant': 'Security_Analyst',
#  'security project manager': 'Project_manager,Security_Analyst',
#  'network & hippa security': 'Project_manager',
#  'it security engineer': 'Security_Analyst',
#  'analyst': 'Software_Developer',
#  'manager, it': 'Project_manager',
#  'hardware support': 'Project_manager',
#  'network and computer systems administrator manager': 'Systems_Administrator,Network_Administrator',
#  'e-commerce specialist, brand ambassador & web developer': 'Web_Developer',
#  'network administrator trainee': 'Network_Administrator',
#  'midwest regional systems administrator': 'Systems_Administrator',
#  'developer, system analyst and dba': 'Database_Administrator',
#  'sun unix system administrator & unix developer & web developer': 'Web_Developer,Systems_Administrator',
#  'front end wordpress developer (contract)': 'Front_End_Developer',
#  'it technician': 'Network_Administrator',
#  'junior systems administrator': 'Systems_Administrator',
#  'senior angular 5 & python developer': 'Python_Developer',
#  'technology services security analyst': 'Security_Analyst',
#  'it network & security analyst': 'Network_Administrator,Security_Analyst',
#  'senior administrative assistant': 'Project_manager',
#  'director, global head of it risk office - ocwen financial corporation': 'Project_manager',
#  'digital strategist & network administrator': 'Network_Administrator',
#  'freelancer front- end developer': 'Front_End_Developer',
#  'network supervisor engineer in zak solutions for computer system': 'Systems_Administrator,Network_Administrator',
#  'it program manager': 'Project_manager',
#  'pmo consultant': 'Project_manager',
#  'crm tier ii help desk analyst - - security clearance': 'Security_Analyst',
#  'business systems analyst': 'Project_manager',
#  'senior software engineer ( python)': 'Software_Developer',
#  'computer network detection (cnd) analyst': 'Network_Administrator',
#  'jr.salesforce admin': 'Java_Developer',
#  'java developer': 'Java_Developer',
#  'senior .net software engineer': 'Software_Developer',
#  'web developer for client falcon technologies': 'Web_Developer',
#  'senior security engineer': 'Security_Analyst',
#  'senior': 'Front_End_Developer',
#  'professional database administrator': 'Database_Administrator',
#  'software developer (intermediate lead)': 'Software_Developer',
#  'sftp server administrator': 'Database_Administrator',
#  'information technology project manager': 'Project_manager',
#  'systems administrator (seasonal)': 'Systems_Administrator',
#  'instructional technology systems administrator': 'Systems_Administrator',
#  'c, c++, python 3, java, sparc v9, vb, vb.net, vba, xml, mips32, junit, x8086 asm, json,pic microcontroller, html5, j2ee, c#, php, managed c++, asp.net javascript, django, css, jsp, python 2 mysql, dynamodb, opengl, processing, swing,directx, windows dom, boost 1.5+, posix, selenium, aws, .net framework, ironpython, imap, smtp, mediawiki, javafx, arobe acrobat sdk, source sdk subversion': 'Java_Developer,Python_Developer',
#  'freelance front- end developer': 'Front_End_Developer',
#  'digital consultant': 'Front_End_Developer',
#  'clarify crm developer': 'Java_Developer',
#  'back-up to system administrator': 'Systems_Administrator',
#  'software development analyst': 'Software_Developer',
#  'website developer': 'Web_Developer',
#  'contract web developer': 'Web_Developer',
#  'ascentium': 'Web_Developer',
#  'senior web developer': 'Web_Developer',
#  'it network': 'Network_Administrator',
#  'system engineer': 'Systems_Administrator,Network_Administrator',
#  'sr. oracle': 'Database_Administrator',
#  'exadata database administrator': 'Database_Administrator',
#  'java developer ip infusion': 'Java_Developer',
#  'application analyst and developer': 'Software_Developer',
#  'desktop support analyst': 'Security_Analyst',
#  'network administrator i infrastructure': 'Network_Administrator',
#  'network support': 'Systems_Administrator,Network_Administrator',
#  'senior front- end ui': 'Front_End_Developer',
#  'ux developer': 'Web_Developer,Front_End_Developer',
#  'snr it technical project': 'Project_manager',
#  'chief information security officer, (ciso)': 'Security_Analyst',
#  'manager, it security risk management': 'Project_manager,Security_Analyst',
#  'software developer ( python)': 'Software_Developer',
#  'javascript, java, sql, html, cascading style sheets (css), mysql, software development, jquery, php, xml, data structures, algorithms, bootstrap, json, web development, databases, object-oriented programming (oop), systems programming, full-stack development, agile methodologies, html5, leadership': 'Java_Developer,Software_Developer',
#  'contract java, pl': 'Java_Developer',
#  'sql developer': 'Web_Developer',
#  'lead programmer': 'Systems_Administrator,Project_manager',
#  'jee architect': 'Java_Developer',
#  'geo-science data analyst and software engineer': 'Software_Developer',
#  'contract - front- end web developer | social media marketing': 'Web_Developer,Front_End_Developer',
#  'senior developer': 'Project_manager',
#  'full stack web developer': 'Web_Developer,Software_Developer,Systems_Administrator',
#  'operations project manager': 'Project_manager',
#  'information technology systems administrator': 'Systems_Administrator',
#  'lead financial project manager': 'Project_manager',
#  'php developer': 'Front_End_Developer',
#  'perl developer': 'Web_Developer,Python_Developer',
#  'tech leader': 'Software_Developer,Project_manager',
#  'associate director - it security, data privacy & compliance': 'Project_manager',
#  'it consultant': 'Systems_Administrator',
#  'sql server dba': 'Database_Administrator',
#  'information technology architect': 'Database_Administrator',
#  'oracle dba': 'Database_Administrator',
#  'software development life cycle (sdlc) (4 years)': 'Software_Developer',
#  'senior application & database administrator': 'Database_Administrator',
#  'intern': 'Project_manager',
#  'senior oracle database administrator': 'Database_Administrator',
#  'cofounder and backend developer': 'Software_Developer',
#  'usu, python programmer': 'Python_Developer',
#  'web developer ,laravel developer': 'Web_Developer',
#  'primary web developer - independent contract': 'Web_Developer',
#  'unix': 'Systems_Administrator',
#  'linux systems administrator': 'Systems_Administrator',
#  'project coordination manager': 'Project_manager',
#  'cyber security consultant': 'Java_Developer,Python_Developer,Security_Analyst',
#  'proficient programming in html5, css, javascript, python, django web framework, javascript, nginx, gunicorn': 'Python_Developer',
#  'c++, java, android trainer cum developer': 'Java_Developer',
#  'it senior delivery manager - medicare advantage emerging markets': 'Project_manager',
#  'defense message system administrator & server administrator': 'Systems_Administrator',
#  'java security developer': 'Java_Developer',
#  'associate software developer': 'Software_Developer',
#  'network administrator iii': 'Network_Administrator',
#  'administrative specialist': 'Project_manager',
#  'it specialist': 'Database_Administrator',
#  'assistant credit manager': 'Project_manager',
#  'assistant referral coordinator': 'Project_manager',
#  'java web developer | freelance': 'Java_Developer,Web_Developer',
#  'react js developer': 'Front_End_Developer',
#  'enterprise systems specialist - analyst': 'Systems_Administrator',
#  'systems': 'Systems_Administrator,Network_Administrator',
#  'network administration (10+ years)': 'Network_Administrator',
#  'it security business analyst': 'Security_Analyst',
#  'oracle dba & oracle developer': 'Database_Administrator',
#  'sr. systems administrator': 'Systems_Administrator,Project_manager',
#  'sharepoint administrator': 'Web_Developer,Front_End_Developer',
#  'junior software': 'Python_Developer,Software_Developer',
#  'it consultant, program manager': 'Project_manager',
#  'sr. it project coordinator': 'Project_manager',
#  'jr. pm': 'Project_manager',
#  'senior linux systems administrator': 'Systems_Administrator',
#  'systems engineer (websphere administrator)': 'Systems_Administrator',
#  'application support engineer': 'Software_Developer',
#  'system': 'Database_Administrator,Systems_Administrator',
#  'jsf developer': 'Java_Developer',
#  'it operations director, senior manager, project manager, senior analyst': 'Project_manager',
#  'it risk security compliance analyst': 'Security_Analyst',
#  'software developer- ii': 'Software_Developer',
#  'accounting': 'Systems_Administrator',
#  'it systems administrator': 'Systems_Administrator,Project_manager',
#  'python test developer': 'Python_Developer',
#  'database architect': 'Database_Administrator',
#  'isso': 'Systems_Administrator',
#  'it service manager': 'Project_manager',
#  'sr. software developer @ cpa network': 'Software_Developer,Network_Administrator',
#  'front- end ux designer & developer': 'Front_End_Developer',
#  'program manager and technical advisor': 'Project_manager',
#  'angularjs, python developer': 'Python_Developer',
#  'senior c+ information security engineer, business analyst ii, checkpoint firewall admin': 'Security_Analyst',
#  'inventory database administrator': 'Database_Administrator',
#  'buyer': 'Database_Administrator',
#  'graphic designer': 'Web_Developer,Front_End_Developer',
#  'ajax web developer - javascript, asp': 'Web_Developer',
#  'senior it resource manager': 'Project_manager',
#  'crm administrator': 'Database_Administrator',
#  'jr. dba': 'Database_Administrator',
#  'web application developer intern (angular7': 'Web_Developer,Software_Developer',
#  '.net web api)': 'Web_Developer,Software_Developer',
#  'sr. security & compliance consultant': 'Security_Analyst',
#  'cwep contractor, software engineer': 'Software_Developer',
#  'lead engineer, senior architect, dba iii': 'Database_Administrator',
#  'systems engineer (tier iii)': 'Systems_Administrator',
#  'it director, assistant vice president': 'Project_manager',
#  'programmer analyst java developer, design, development': 'Java_Developer',
#  'erp system administrator': 'Systems_Administrator',
#  'front end development manager': 'Front_End_Developer',
#  'web developer (student)': 'Web_Developer',
#  'front- end developer and project manager': 'Project_manager,Front_End_Developer',
#  'principal security engineer': 'Security_Analyst',
#  'sr django': 'Web_Developer,Python_Developer',
#  'software developer - salesforce': 'Java_Developer,Software_Developer',
#  'senior scientific software developer': 'Software_Developer',
#  'network administrator and penetration testing': 'Network_Administrator',
#  'regional program manager': 'Project_manager',
#  'software engineer internship': 'Software_Developer',
#  'application': 'Web_Developer',
#  'software developer trainee': 'Software_Developer',
#  'web designer & lead developer': 'Web_Developer',
#  'mis director': 'Database_Administrator,Systems_Administrator',
#  'homeless management information systems database administrator': 'Database_Administrator,Systems_Administrator',
#  'director of project management & market research': 'Project_manager',
#  'sr. saas operation engineer': 'Network_Administrator',
#  'adobe creative suite, adobe dreamweaver, adobe photoshop, agile & waterfall methodologies, algorithms, anti-virus, asset management, brand strategy, branding, business analysis, business process improvement, content design, crystal reports, digital innovation, due diligence, editing, enterprise software, event planning, floor plans, hardware, help desk, higher education, hiring, html, human resources (hr), incident response, information security, integration, internal communications, interpersonal skills, jira, layouts, managers, marketing agency, mentoring, mergers & acquisitions (m&a), microsoft office, microsoft sql server, mobile applications, mobile product development, ms excel, ms office, ms outlook, ms powerpoint, ms word, multi-tasker, microsoft and apple os, problem solving, product management, production management, programming, project coordination, project planning, project management office (pmo), project management professional, project metrics, requirements analysis, scheduling, schematics, scuba diving , security operations, social media, social networking, software development life cycle (sdlc), software documentation, spanish, start-up environment, teamwork, time management, tracker, training, trend analysis, troubleshooting, user interface design, waterfall project management, web design': 'Software_Developer',
#  'network administrator manager': 'Network_Administrator',
#  'sr. lead java j2ee developer': 'Java_Developer,Web_Developer',
#  'offshore software development (10+ years)': 'Software_Developer',
#  'system administrator & engineer support tech': 'Systems_Administrator',
#  'security consultant': 'Security_Analyst',
#  'senior java fullstack developer, fixed income': 'Java_Developer',
#  'project manager, it service management': 'Project_manager',
#  'international project manager': 'Project_manager',
#  'technical project manager - implementation': 'Project_manager',
#  'web developer software engineer': 'Web_Developer,Software_Developer',
#  'performance analyst': 'Java_Developer',
#  'manager, customer & product support it': 'Project_manager',
#  'project manager - app dev - contract': 'Project_manager',
#  'senior linux systems engineer': 'Systems_Administrator',
#  'product development engineer, python developer, data analyst': 'Python_Developer',
#  'database engineer': 'Database_Administrator',
#  'director': 'Project_manager',
#  'java j2ee (5 years)': 'Java_Developer',
#  'purchasing agent & network administrator': 'Network_Administrator',
#  'it support': 'Project_manager,Network_Administrator',
#  'management, network': 'Systems_Administrator,Network_Administrator',
#  'i.t. service delivery manager': 'Project_manager',
#  'senior oracle and java developer': 'Java_Developer',
#  'senior network engineer': 'Network_Administrator',
#  'project manager & business analyst (fte)': 'Project_manager',
#  'manager, network and it operations (promotion)': 'Project_manager',
#  'database administrator i, consumer lending department': 'Database_Administrator',
#  'software engineer .net developer': 'Web_Developer,Software_Developer',
#  'network operations analyst (noc)': 'Network_Administrator',
#  'front- end w eb developer': 'Front_End_Developer',
#  'computer security systems analyst': 'Security_Analyst',
#  'it applications migration manager': 'Project_manager',
#  'corporate risk project manager': 'Project_manager',
#  'senior system engineer (consultant)': 'Systems_Administrator',
#  'it program': 'Project_manager',
#  'systems administrator, it specialist': 'Systems_Administrator',
#  'helpdesk support': 'Systems_Administrator,Network_Administrator',
#  'software developer engineer in test intern': 'Software_Developer',
#  'android developer': 'Web_Developer',
#  'computer security it specialist': 'Security_Analyst',
#  'architect': 'Software_Developer',
#  'it project coordinator - contract': 'Project_manager',
#  'web developer -- freelance': 'Web_Developer',
#  'lead system administrator': 'Systems_Administrator,Security_Analyst',
#  'agile coach': 'Project_manager',
#  'transformation lead consultant - it security': 'Security_Analyst',
#  'senior open systems administrator': 'Systems_Administrator',
#  'sr. it project manager (consultant)': 'Project_manager',
#  'oracle': 'Database_Administrator',
#  'ms sql server database administrator': 'Database_Administrator',
#  'senior solution designer, project manager & developer': 'Project_manager',
#  'python back end developer': 'Python_Developer',
#  'web manager': 'Network_Administrator',
#  'senior systems administrator for scom and sccm': 'Systems_Administrator',
#  'web design, application development, python, html': 'Web_Developer,Software_Developer',
#  'css, javascript': 'Web_Developer,Software_Developer',
#  'ajax, mysql and php (mamp': 'Web_Developer,Software_Developer',
#  'lamp': 'Software_Developer',
#  'wamp), adobe photoshop, illustrator, indesign and bridge, microsoft sharepoint 2010 and 2013': 'Web_Developer,Software_Developer',
#  'client support specialist': 'Front_End_Developer',
#  'lead security engineer (contractor), infogroup': 'Security_Analyst',
#  'lead graphic designer & front end developer': 'Front_End_Developer',
#  'lead business analyst': 'Project_manager',
#  'it project manager (consulting)': 'Project_manager',
#  'service desk analyst- firewall support': 'Security_Analyst',
#  'security': 'Security_Analyst',
#  'information assurance systems engineer': 'Systems_Administrator',
#  'systems and software administrator': 'Systems_Administrator',
#  'sql database administrator ii': 'Database_Administrator',
#  'senior computer systems administrator': 'Systems_Administrator',
#  'software development consultant, smiletechlab, ny': 'Software_Developer',
#  'network applications engineer': 'Network_Administrator',
#  'angular': 'Front_End_Developer',
#  'software developer, randstad contractor': 'Software_Developer',
#  'senior network administrator': 'Network_Administrator',
#  'proprietary systems specialist ii': 'Systems_Administrator',
#  'technical support': 'Front_End_Developer',
#  'analyst, infrastructure': 'Systems_Administrator',
#  'system engineer - level 1': 'Systems_Administrator',
#  'technology analyst -- java': 'Java_Developer',
#  'it project manager - project': 'Project_manager',
#  'ops manger': 'Project_manager',
#  'email specialist, e-commerce front end developer, technical': 'Front_End_Developer',
#  'team lead of global development team building java middle tier': 'Java_Developer',
#  'backend applications': 'Java_Developer',
#  'front end web developer, associate': 'Web_Developer,Front_End_Developer',
#  'it': 'Project_manager',
#  'security specialist': 'Security_Analyst',
#  'web content manager, developer': 'Web_Developer',
#  'volunteer project manager': 'Project_manager',
#  'information systems security officer (isso) & network administrator': 'Systems_Administrator,Network_Administrator,Security_Analyst',
#  'application systems support specialist': 'Systems_Administrator',
#  'software development (2 years)': 'Software_Developer',
#  'server and network security consultant': 'Network_Administrator,Security_Analyst',
#  'sr. front-end ui developer': 'Front_End_Developer',
#  'systems support specialist (sss)': 'Systems_Administrator',
#  'lead ux designer': 'Web_Developer',
#  'it security officer for coa & network administrator': 'Network_Administrator,Security_Analyst',
#  'homeland security (dhs) analyst': 'Security_Analyst',
#  'jr. front end ui developer': 'Front_End_Developer',
#  'motion capture supervisor': 'Software_Developer',
#  'guide': 'Web_Developer',
#  'maintenance': 'Web_Developer',
#  'corporate security data analyst - finance': 'Security_Analyst',
#  'security desk analyst': 'Security_Analyst',
#  'system accountant': 'Systems_Administrator,Network_Administrator',
#  'system administrator (10+ years)': 'Systems_Administrator',
#  'project manager, it manager': 'Project_manager',
#  'senior it engineering program manager': 'Project_manager',
#  'director of web services': 'Database_Administrator',
#  'web & database programmer': 'Database_Administrator',
#  'it security analyst ii - active directory': 'Security_Analyst',
#  'senior application developer': 'Software_Developer,Systems_Administrator',
#  'sr network security engineer': 'Network_Administrator,Security_Analyst',
#  'intelligence specialist': 'Database_Administrator',
#  'i.t. technician': 'Project_manager,Network_Administrator',
#  'django developer': 'Web_Developer,Python_Developer',
#  'it technical delivery manager': 'Project_manager',
#  'it risk assurance': 'Security_Analyst',
#  'information systems security officer': 'Security_Analyst',
#  'information security assurance officer': 'Network_Administrator,Security_Analyst',
#  'web developer (asp.net), hvg': 'Web_Developer',
#  'cloud systems administrator': 'Systems_Administrator',
#  'contract and freelance web developer': 'Web_Developer',
#  'go developer': 'Python_Developer',
#  'web developer volunteer': 'Web_Developer',
#  'sr. software engineer (applications designer, developer advisor)': 'Software_Developer',
#  'java web services': 'Java_Developer,Web_Developer',
#  'soa developer': 'Java_Developer,Web_Developer',
#  'director, it applications': 'Project_manager',
#  'sql database developer': 'Database_Administrator',
#  'project manager supervisor, quality assurance': 'Project_manager',
#  'it project manager- network and infrastructure': 'Project_manager',
#  'pipeline python developer': 'Python_Developer',
#  'lead web developer and user experience engineer': 'Web_Developer',
#  'frontend developer & lead ux developer': 'Front_End_Developer',
#  'field technician': 'Network_Administrator',
#  'director it infrastructure (technical services & operations)': 'Project_manager',
#  'process manager': 'Network_Administrator',
#  'network control centre admin support': 'Network_Administrator',
#  'senior web application developer (contractor)': 'Web_Developer,Software_Developer',
#  'director of applications and software development': 'Software_Developer,Project_manager',
#  'quarterly enhancement project manager ii - contractor': 'Project_manager',
#  'data network specialist in iii marine expeditionary force': 'Systems_Administrator,Network_Administrator',
#  'seinor network administrator (contract)': 'Network_Administrator',
#  'hardware and embedded systems engineer': 'Systems_Administrator',
#  'data systems field engineer': 'Systems_Administrator',
#  'iw technician': 'Systems_Administrator',
#  'systems administrator for genesis project': 'Systems_Administrator',
#  'systems software senior engineer': 'Software_Developer,Systems_Administrator',
#  'oxford-uk global project manager': 'Project_manager',
#  'it acquisition manager': 'Project_manager',
#  'sole database administrator': 'Database_Administrator',
#  'software configuration': 'Software_Developer',
#  'application developer': 'Database_Administrator,Software_Developer',
#  'manager, it project management office (consultant)': 'Project_manager',
#  'multimedia web developer': 'Web_Developer',
#  'sap basis': 'Database_Administrator',
#  'software qa engineer': 'Java_Developer,Software_Developer',
#  'network security analyst contracted': 'Network_Administrator,Security_Analyst',
#  'full-stack (lamp) web developer': 'Web_Developer',
#  'it project coordinator & it data analyst': 'Project_manager',
#  'mac systems administrator': 'Systems_Administrator',
#  'it consultant and web developer': 'Web_Developer,Software_Developer',
#  'program': 'Project_manager',
#  'project manager and it partner': 'Project_manager',
#  'agile software development (10+ years)': 'Software_Developer',
#  'developer and software engineer': 'Software_Developer',
#  'program escalation manager': 'Project_manager',
#  'project coordinator': 'Project_manager',
#  'consultant - it project manager': 'Project_manager',
#  'front end development intern': 'Front_End_Developer',
#  'senior front web developer': 'Web_Developer',
#  'webmaster': 'Network_Administrator',
#  'angular- python developer': 'Python_Developer',
#  'joint detention group s6': 'Project_manager',
#  'it security analyst, extended term consultant': 'Security_Analyst',
#  'senior python web developer': 'Web_Developer,Python_Developer',
#  'database project engineer': 'Database_Administrator',
#  'web marketing manager, seo , front end developer - web designer': 'Web_Developer,Front_End_Developer',
#  'application engineer iv': 'Software_Developer',
#  'project manager, web-based applications': 'Project_manager',
#  'associate software development project manager, contractor - hms': 'Software_Developer,Project_manager',
#  'jr python developer': 'Python_Developer',
#  'web and mobile application developer': 'Web_Developer,Software_Developer',
#  'erp & database administrator': 'Database_Administrator,Project_manager',
#  'database manager': 'Database_Administrator',
#  'sr. oracle dba': 'Database_Administrator',
#  'lead': 'Database_Administrator',
#  'front- end developer lead full time': 'Front_End_Developer',
#  'software engineer (salesforce)': 'Software_Developer',
#  'it security analyst & project administrator intern': 'Security_Analyst',
#  'photographer & editor': 'Web_Developer',
#  'security analyst (contractor through teksystems)': 'Security_Analyst',
#  'sr. ui': 'Front_End_Developer',
#  'it cyber security project manager, national health insurance project (nhia) project': 'Project_manager,Security_Analyst',
#  'it project manager & infrastructure architect': 'Project_manager',
#  'it manager, application infrastructure management services': 'Project_manager',
#  'research assistant, python programmer': 'Python_Developer',
#  'contract software developer': 'Software_Developer',
#  'intern application developer': 'Software_Developer',
#  'jr. marketing and web developer': 'Web_Developer',
#  'project manager - custom software development': 'Software_Developer,Project_manager',
#  'project delivery manager': 'Project_manager',
#  'lead desktop': 'Systems_Administrator,Network_Administrator',
#  'physical security specialist': 'Security_Analyst',
#  'software developer and billing department manager': 'Software_Developer',
#  'developer, software team': 'Software_Developer',
#  'full stack software developer student': 'Software_Developer',
#  'full stack web developer, seo manager': 'Web_Developer',
#  'r&d': 'Systems_Administrator',
#  'part-time front end developer': 'Front_End_Developer',
#  'web developer and administrator': 'Web_Developer',
#  'network engineer (snp)': 'Network_Administrator',
#  'service introduction': 'Project_manager',
#  'webdev': 'Systems_Administrator',
#  'director it cloud and application support': 'Project_manager',
#  'information systems security officer (lss0)': 'Security_Analyst',
#  'sql server developer': 'Database_Administrator',
#  'dba': 'Database_Administrator',
#  'contract web developer for pimco': 'Web_Developer',
#  'technical team lead': 'Database_Administrator',
#  'system administrator - systems integration': 'Systems_Administrator',
#  'javascript': 'Web_Developer',
#  'software developer mts - lucent sip stack': 'Software_Developer',
#  'it security specialist': 'Security_Analyst',
#  'offshore dba': 'Database_Administrator',
#  'ios': 'Web_Developer,Python_Developer',
#  'android': 'Database_Administrator,Java_Developer',
#  'application analyst': 'Software_Developer',
#  'network security': 'Network_Administrator,Security_Analyst',
#  'front- end developer, horizontal integration': 'Front_End_Developer',
#  'java app developer': 'Java_Developer',
#  'senior database administrator - technical lead': 'Database_Administrator',
#  'security response center sr analyst': 'Security_Analyst',
#  'system administrator (novell, windowsnt, 2000': 'Systems_Administrator',
#  'sr. software engineer': 'Software_Developer',
#  'scrum master': 'Web_Developer,Project_manager',
#  'pricing and pc support': 'Network_Administrator',
#  'network security engineer, internal it': 'Network_Administrator,Security_Analyst',
#  'software development coordinator': 'Software_Developer',
#  'network engineer & system administrator': 'Systems_Administrator,Network_Administrator',
#  'technical lead': 'Software_Developer',
#  'associate it security analyst': 'Security_Analyst',
#  'aws': 'Python_Developer',
#  'java architect': 'Java_Developer',
#  'solution integrator - oracle database administrator': 'Database_Administrator',
#  'security ops center it security analyst': 'Security_Analyst',
#  'python dev engineer': 'Python_Developer',
#  'agile project manager': 'Project_manager',
#  'it infrastructure systems administrator': 'Systems_Administrator',
#  'sr. systems administrator & webmaster': 'Systems_Administrator',
#  'contractor on a web application called': 'Web_Developer',
#  'it security specialist iv': 'Security_Analyst',
#  'ui lead': 'Front_End_Developer',
#  'sr. java frontend ui developer': 'Java_Developer,Front_End_Developer',
#  'senior sql dba': 'Database_Administrator',
#  'bi': 'Project_manager',
#  '(ui developer)': 'Front_End_Developer',
#  'development, maintenance, devops and qa as lamp': 'Java_Developer,Python_Developer',
#  'perl': 'Python_Developer',
#  'it security specialist ii': 'Security_Analyst',
#  'pos database administrator': 'Database_Administrator',
#  'web developer and designer (freelance)': 'Web_Developer',
#  'program manager for the veterans administration in hines, il': 'Project_manager',
#  'contract front- end web designer': 'Web_Developer,Front_End_Developer',
#  'senior principal software engineer': 'Software_Developer',
#  'contract sr. project manager (comcast)': 'Project_manager',
#  'project manager - sales - front end developer': 'Project_manager,Front_End_Developer',
#  'network administrator, team lead': 'Network_Administrator',
#  'consulting project manager': 'Project_manager',
#  'sr. project manager': 'Project_manager',
#  'junior front- end web developer': 'Web_Developer,Front_End_Developer',
#  'sr. security analyst': 'Security_Analyst',
#  'software test engineer': 'Software_Developer,Network_Administrator',
#  'devops engineer': 'Systems_Administrator',
#  'front- end developer - contractor, (react.js)': 'Front_End_Developer',
#  'sql database administrator (dba)': 'Database_Administrator',
#  'ios developer intern': 'Web_Developer',
#  'front end ux web developer and consultant': 'Web_Developer,Front_End_Developer',
#  'web developer & design lead': 'Web_Developer',
#  'information analysts': 'Project_manager',
#  'telecom program manager': 'Project_manager',
#  'global network administrator': 'Network_Administrator',
#  'java & mean stack developer': 'Java_Developer',
#  'it project management coordinator': 'Project_manager',
#  'short-term contract consultant as senior project manager': 'Project_manager',
#  'strategic project manager': 'Project_manager',
#  'junior database administrator intern': 'Database_Administrator',
#  'information assurance security officer': 'Systems_Administrator,Security_Analyst',
#  'assistant it project manager': 'Project_manager',
#  'facilities and project manager': 'Project_manager',
#  'senior it security analyst': 'Security_Analyst',
#  'invincea': 'Security_Analyst',
#  'global support software developer': 'Software_Developer',
#  'senior manager - it customer service': 'Project_manager',
#  'owner and web developer': 'Web_Developer',
#  'project manager | juvenile liaison': 'Project_manager',
#  'web developer and systems analyst': 'Web_Developer',
#  'global it project': 'Project_manager',
#  'full time manager technical support': 'Network_Administrator',
#  'sr. network engineer': 'Network_Administrator',
#  'java developer, oss': 'Java_Developer',
#  'senior systems administrator & infrastructure technical support': 'Systems_Administrator',
#  'méxico python developer (internship)': 'Python_Developer',
#  'information system security officer': 'Security_Analyst',
#  'disa jsp v&v analyst': 'Security_Analyst',
#  'blue team security auditor': 'Security_Analyst',
#  'sr web developer': 'Web_Developer',
#  'marketplace, software engineer intern': 'Software_Developer',
#  'microservices backend developer': 'Software_Developer',
#  'project analyst': 'Project_manager',
#  'sharepoint administrator (pmo) project': 'Project_manager',
#  'full stack .net': 'Web_Developer',
#  'site systems administrator': 'Systems_Administrator',
#  'python & vc++ developer': 'Python_Developer',
#  'information systems security engineer': 'Systems_Administrator,Security_Analyst',
#  'site lead': 'Systems_Administrator',
#  'dba, software engineer, programmer, database developer': 'Database_Administrator,Software_Developer',
#  'motorcycle technician': 'Network_Administrator',
#  'computer and network administrator': 'Network_Administrator',
#  'sr. cyber security policy & compliance analyst': 'Security_Analyst',
#  'sr. lan administrator': 'Network_Administrator',
#  'database engineer senior': 'Database_Administrator',
#  'junior database engineer': 'Database_Administrator',
#  'finance operations admin - lead database management': 'Database_Administrator',
#  'it procurement associate manager': 'Project_manager',
#  'youth program manager': 'Project_manager',
#  'software and support engineer': 'Software_Developer',
#  'web app developer (contract)': 'Web_Developer',
#  'business applications it project manager': 'Project_manager',
#  'systems administrator (mid)': 'Systems_Administrator',
#  'enterprise linux systems administrator': 'Systems_Administrator',
#  'java web application - traffic navigation system': 'Java_Developer,Web_Developer',
#  'software developer - .net developer': 'Web_Developer,Software_Developer',
#  'j2ee 1.8, restful web services, soap web services, soap ui, spring mvc, spring ioc, spring batch, spring security, spring boot, microservices, jdbc, jms,jpa, hibernate, apache poi, selenium web driver, junit, mockito, log4j, jsp,html,css, bootstrap, angularjs, node.js, less, bower, grunt, express js, uml, apache tomcat 7.0.x, mysql, mongodb, eclipse, maven, git, stash, jira. (8 years)': 'Java_Developer',
#  'system administrator ( security) threat and vulnerability management team': 'Systems_Administrator',
#  'it security & identity access analyst i': 'Security_Analyst',
#  'managing dba consultant': 'Database_Administrator',
#  'software architect, java and c++ developer (consultant)': 'Java_Developer,Software_Developer',
#  'systems & network administrator, allegro pacific philippines': 'Systems_Administrator,Network_Administrator',
#  'it service desk supervisor': 'Security_Analyst',
#  'information security analyst': 'Security_Analyst',
#  'district network engineer': 'Network_Administrator',
#  'senior information security program manager (risk, policy, governance & operations)': 'Project_manager',
#  'dba (5 years)': 'Database_Administrator',
#  'tier 3 systems engineer': 'Systems_Administrator',
#  'solution architect, team lead, specialist, developer, project manager, vice president, doing multi-tiered applications, big data, business intelligence (bi), data warehousing machine learning, deep learning, system engineering (10+ years)': 'Project_manager',
#  'java ui': 'Java_Developer,Front_End_Developer',
#  'internship database administrator': 'Database_Administrator',
#  'web developer, stg': 'Web_Developer,Software_Developer',
#  'it development administrator': 'Software_Developer',
#  'lead developer': 'Project_manager',
#  'senior web designer': 'Web_Developer',
#  'it sr. iam project manager-pmo (consulting position)': 'Project_manager',
#  'vmware engineer': 'Java_Developer',
#  'sr. systems engineer': 'Database_Administrator,Systems_Administrator',
#  'mis project manager': 'Project_manager',
#  'business growth consulting': 'Software_Developer',
#  'custom software development': 'Software_Developer',
#  'custom web development': 'Software_Developer',
#  'apply innovative marketing & advertising strategies': 'Software_Developer',
#  'increase brand recognition & market penetration': 'Software_Developer',
#  'develop & execute strategic plans, managing projects from inception to completion': 'Software_Developer',
#  'form strategic alliances for cross promotional purposes': 'Software_Developer',
#  'complete email marketing': 'Software_Developer',
#  'search engine dominance (advanced search engine optimization - seo)': 'Software_Developer',
#  'online reputation management': 'Software_Developer',
#  'google adwords ppc management': 'Software_Developer',
#  'social media growth consulting': 'Software_Developer',
#  'instagram sponsored ad management': 'Software_Developer',
#  'advanced retargeting campaigns': 'Software_Developer',
#  'integrated ad campaigns': 'Software_Developer',
#  'digital content writing': 'Software_Developer',
#  'database management & custom database development': 'Software_Developer',
#  'complete e-commerce design & management': 'Software_Developer',
#  'logo design and branding': 'Software_Developer',
#  'custom shopify management': 'Software_Developer',
#  'corporate image branding': 'Software_Developer',
#  'sales funnel execution': 'Software_Developer',
#  'corporate sales training': 'Software_Developer',
#  'email management': 'Software_Developer',
#  'hosting services': 'Software_Developer',
#  'custom crm creation': 'Software_Developer',
#  'facebook sponsored ad management': 'Software_Developer',
#  'ops manager': 'Project_manager',
#  'senior staff database administrator': 'Database_Administrator',
#  'help desk technician': 'Systems_Administrator',
#  'system & security analyst': 'Security_Analyst',
#  'web developer web designer': 'Web_Developer',
#  'front-end wordpress developer': 'Front_End_Developer',
#  'security messaging analyst': 'Security_Analyst',
#  'enterprise application administrator ( database and automation architect)': 'Database_Administrator',
#  'marketing analysis, front- end developer': 'Front_End_Developer',
#  'network deployment engineer tampa': 'Network_Administrator',
#  'sr. engineered systems engineer': 'Systems_Administrator',
#  'systems administrator and management': 'Systems_Administrator',
#  'national consultant': 'Project_manager',
#  'business intelligence': 'Project_manager',
#  'business analyst-web developer': 'Web_Developer,Software_Developer',
#  'it helpdesk': 'Systems_Administrator,Project_manager',
#  'networking': 'Web_Developer,Software_Developer',
#  'it release manager': 'Project_manager',
#  'sr. it application project manager': 'Project_manager',
#  'enterprise mssql database administrator': 'Database_Administrator',
#  'technology program manager': 'Project_manager',
#  'project management (consultant)': 'Systems_Administrator,Network_Administrator',
#  'oracle dba lead': 'Database_Administrator',
#  'it expert': 'Systems_Administrator',
#  'intern- it programming analyst': 'Software_Developer',
#  'oracle systems developer': 'Web_Developer,Systems_Administrator',
#  'web & graphic designer': 'Web_Developer,Front_End_Developer',
#  'help desk db admin': 'Web_Developer,Systems_Administrator',
#  'application librarian': 'Database_Administrator',
#  'team chief, network administrator, satellite communication expert, radio operator instructor': 'Network_Administrator',
#  'outsystems it systems administrator': 'Systems_Administrator',
#  'junior it security analyst': 'Security_Analyst',
#  'independent security assessor': 'Security_Analyst',
#  'web project manager - web developer': 'Web_Developer,Project_manager',
#  'business manager': 'Database_Administrator',
#  'services project manager - ca services, it security': 'Project_manager,Security_Analyst',
#  'senior lead web': 'Web_Developer',
#  'mobile developer': 'Web_Developer',
#  'team leader': 'Software_Developer',
#  'development dba': 'Database_Administrator',
#  'sr. scrum master': 'Project_manager',
#  'oracle developer': 'Java_Developer',
#  'project manager analyst (contract)': 'Project_manager',
#  'java full stack': 'Java_Developer,Front_End_Developer',
#  'information systems administrator': 'Systems_Administrator',
#  'vtc lead': 'Systems_Administrator',
#  'core network security analyst': 'Network_Administrator,Security_Analyst',
#  'network administration (3 years)': 'Network_Administrator',
#  'senior it manager -- contract management': 'Project_manager',
#  'junior developer ( java spring boot) intern': 'Java_Developer',
#  'lead ui software engineer': 'Software_Developer',
#  'database security architect consultant': 'Security_Analyst',
#  'software engineering intern, python developer': 'Python_Developer,Software_Developer',
#  'senior python developer aws': 'Python_Developer',
#  'sr. postgresql dba': 'Database_Administrator',
#  'web devleoper & custom software developer': 'Web_Developer,Software_Developer',
#  'program manager - consultant': 'Project_manager',
#  'store system engineer': 'Systems_Administrator',
#  'professional systems administrator - united technologies corporation': 'Systems_Administrator',
#  'it manager, unix system administration': 'Project_manager',
#  'it project manager consultant - finance and hr': 'Project_manager',
#  'security & compliance project manager': 'Project_manager',
#  'help desk specialist': 'Systems_Administrator',
#  'web-app developer': 'Web_Developer',
#  'python curriculum developer (internship)': 'Python_Developer',
#  'sr. java developer at amex': 'Java_Developer',
#  'sole software developer': 'Software_Developer',
#  'itil v3 foundation (it service management) ----- vcp 5 vmware certified professional ----- ccee citrix certified enterprise engineer ----- ccaa xenapp advanced administration ----- cca citrix xenapp 6.5 ----- cca citrix xendesktop 5 ----- cca citrix xenserver 6 ----- ccna cisco certified network associate (2013) ----- network+': 'Network_Administrator',
#  'oracle and aws database administrator': 'Database_Administrator',
#  'it administrator': 'Database_Administrator',
#  'data entry specialist, database administrators': 'Database_Administrator',
#  'network administrator & support': 'Network_Administrator',
#  'security consultant (contractor)': 'Security_Analyst',
#  'jasper developer': 'Java_Developer',
#  'it healthcare project manager-consultant': 'Project_manager',
#  'technical support manager, systems engineer ii': 'Systems_Administrator',
#  'network solution administrator': 'Network_Administrator',
#  'ui designer, senior web developer': 'Web_Developer,Front_End_Developer',
#  'technical lead, senior software designer, developer and system': 'Software_Developer',
#  'lead front end web developer': 'Web_Developer,Front_End_Developer',
#  'service manager': 'Project_manager',
#  ...}

# %%
def normalize_occupations(row, normalized_mapping):
    occupations = row['Occupations'].lower().split(';')
    normalized_occupations_set = set()  # Use a set to store unique normalized occupations

    for occ in occupations:
        normalized_occ = normalized_mapping.get(occ.strip(), None)
        if normalized_occ:
            normalized_occupations_set.add(normalized_occ)

    normalized_occupations = list(normalized_occupations_set)
    return ';'.join(normalized_occupations)

# %%
resume_data['Normalized_Occupation'] = resume_data.apply(normalize_occupations, args=(normalised_mapping,), axis=1)
resume_data.head()
# Out:
#                                                   ID  \
# 0  C:\Workspace\java\scrape_indeed\dba_part_1\1.h...
# 1  C:\Workspace\java\scrape_indeed\dba_part_1\10....
# 2  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 3  C:\Workspace\java\scrape_indeed\dba_part_1\100...
# 4  C:\Workspace\java\scrape_indeed\dba_part_1\100...
#
#                                          Occupations  \
# 0  Database Administrator;Database Administrator;...
# 1  Database Administrator;SQL, Microsoft PowerPoi...
# 2  Oracle Database Administrator;Oracle Database ...
# 3  Amazon Redshift Administrator and ETL Develope...
# 4  Scrum Master;Oracle Database Administrator/ Sc...
#
#                                               Resume                  Labels  \
# 0  Database Administrator <span class="hl">Databa...  Database_Administrator
# 1  Database Administrator <span class="hl">Databa...  Database_Administrator
# 2  Oracle Database Administrator Oracle <span cla...  Database_Administrator
# 3  Amazon Redshift Administrator and ETL Develope...  Database_Administrator
# 4  Scrum Master Scrum Master Scrum Master Richmon...  Database_Administrator
#
#                                Normalized_Occupation
# 0  Front_End_Developer;Database_Administrator,Sys...
# 1               Database_Administrator,Web_Developer
# 2  Database_Administrator;Front_End_Developer;Sys...
# 3  Database_Administrator;Database_Administrator,...
# 4  Web_Developer,Project_manager;Database_Adminis...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rajat\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
lemmatizer = WordNetLemmatizer()

def preprocess_resume_text(text):
    # Remove HTML tags and special characters using regular expressions
    cleaned_text = re.sub(r'<[^>]+>', ' ', text)
    cleaned_text = re.sub(r'[^\w.+/#-]', ' ', cleaned_text)

    # Convert to lowercase
    cleaned_text = cleaned_text.lower()

    #Tokenize text into words
    words = word_tokenize(cleaned_text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words]
    
    lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]

    # Join words back into a single string
    preprocessed_text = ' '.join(filtered_words)

    return preprocessed_text

# %%
resume_data['Preprocessed_Resume'] = resume_data['Resume'].apply(preprocess_resume_text)

# %%
output_file_path = 'C:/Coding/Jupyter notebooks/resume_data1.csv'

# Save the 'resume_data' DataFrame as a CSV file
resume_data.to_csv(output_file_path, index=False)

print("DataFrame saved as CSV file successfully.")
# Out:
# DataFrame saved as CSV file successfully.

# %%
norm_labels = [labels.split(';') for labels in resume_data['Normalized_Occupation']]
unique_classes = set()

# Loop through each row in y_train_labels and split the labels
for row in norm_labels:
    unique_classes.update(row)

# Convert the set back to a list for indexing
class_list = list(unique_classes)
class_list
# Out:
# ['',
#  'Software_Developer,Systems_Administrator,Project_manager',
#  'Database_Administrator,Python_Developer',
#  'Database_Administrator,Front_End_Developer',
#  'Java_Developer,Software_Developer',
#  'Java_Developer,Front_End_Developer',
#  'Python_Developer,Network_Administrator',
#  'Database_Administrator,Software_Developer,Systems_Administrator',
#  'Web_Developer,Software_Developer,Systems_Administrator',
#  'Web_Developer,Systems_Administrator',
#  'Web_Developer,Python_Developer,Software_Developer',
#  'Database_Administrator,Java_Developer,Python_Developer,Software_Developer',
#  'Systems_Administrator,Project_manager',
#  'Software_Developer,Systems_Administrator',
#  'Systems_Administrator,Project_manager,Security_Analyst',
#  'Java_Developer,Python_Developer',
#  'Database_Administrator,Software_Developer,Systems_Administrator,Security_Analyst',
#  'Systems_Administrator,Network_Administrator,Security_Analyst',
#  'Database_Administrator,Systems_Administrator',
#  'Project_manager,Network_Administrator',
#  'Java_Developer,Python_Developer,Network_Administrator',
#  'Software_Developer,Project_manager,Security_Analyst',
#  'Security_Analyst',
#  'Network_Administrator,Security_Analyst',
#  'Database_Administrator,Security_Analyst',
#  'Project_manager,Network_Administrator,Security_Analyst',
#  'Web_Developer,Software_Developer,Front_End_Developer',
#  'Java_Developer,Project_manager',
#  'Python_Developer,Systems_Administrator',
#  'Java_Developer,Python_Developer,Software_Developer',
#  'Project_manager,Security_Analyst',
#  'Systems_Administrator',
#  'Database_Administrator,Systems_Administrator,Project_manager',
#  'Project_manager,Front_End_Developer',
#  'Python_Developer,Security_Analyst',
#  'Java_Developer,Web_Developer',
#  'Java_Developer,Network_Administrator',
#  'Software_Developer,Project_manager',
#  'Python_Developer,Front_End_Developer',
#  'Java_Developer,Web_Developer,Python_Developer',
#  'Database_Administrator,Java_Developer',
#  'Python_Developer,Project_manager',
#  'Web_Developer,Systems_Administrator,Front_End_Developer',
#  'Database_Administrator,Web_Developer,Software_Developer',
#  'Web_Developer,Python_Developer',
#  'Database_Administrator,Network_Administrator',
#  'Network_Administrator,Front_End_Developer',
#  'Java_Developer,Systems_Administrator,Network_Administrator',
#  'Java_Developer,Systems_Administrator',
#  'Systems_Administrator,Security_Analyst',
#  'Web_Developer,Project_manager',
#  'Web_Developer,Network_Administrator',
#  'Python_Developer',
#  'Web_Developer',
#  'Web_Developer,Front_End_Developer',
#  'Web_Developer,Software_Developer,Project_manager',
#  'Systems_Administrator,Network_Administrator',
#  'Software_Developer,Front_End_Developer',
#  'Systems_Administrator,Project_manager,Network_Administrator',
#  'Java_Developer,Web_Developer,Software_Developer',
#  'Software_Developer',
#  'Database_Administrator,Systems_Administrator,Network_Administrator',
#  'Web_Developer,Software_Developer,Security_Analyst',
#  'Python_Developer,Software_Developer',
#  'Java_Developer,Web_Developer,Project_manager',
#  'Network_Administrator',
#  'Database_Administrator,Software_Developer',
#  'Software_Developer,Security_Analyst',
#  'Java_Developer',
#  'Project_manager',
#  'Front_End_Developer',
#  'Java_Developer,Python_Developer,Security_Analyst',
#  'Software_Developer,Network_Administrator',
#  'Database_Administrator,Systems_Administrator,Security_Analyst',
#  'Web_Developer,Software_Developer',
#  'Database_Administrator',
#  'Java_Developer,Web_Developer,Front_End_Developer',
#  'Web_Developer,Security_Analyst',
#  'Database_Administrator,Project_manager',
#  'Web_Developer,Python_Developer,Front_End_Developer',
#  'Database_Administrator,Web_Developer',
#  'Database_Administrator,Software_Developer,Project_manager',
#  'Python_Developer,Software_Developer,Systems_Administrator',
#  'Software_Developer,Systems_Administrator,Network_Administrator',
#  'Database_Administrator,Project_manager,Network_Administrator']

# %%
resume_data[resume_data['Normalized_Occupation']=='']
# Out:
#                                                       ID  \
# 91     C:\Workspace\java\scrape_indeed\dba_part_1\108...
# 163    C:\Workspace\java\scrape_indeed\dba_part_1\114...
# 322    C:\Workspace\java\scrape_indeed\dba_part_1\129...
# 357    C:\Workspace\java\scrape_indeed\dba_part_1\132...
# 498    C:\Workspace\java\scrape_indeed\dba_part_1\145...
# ...                                                  ...
# 29530  C:\Workspace\java\scrape_indeed\web_dev_part_1...
# 29609  C:\Workspace\java\scrape_indeed\web_dev_part_1...
# 29648  C:\Workspace\java\scrape_indeed\web_dev_part_1...
# 29661  C:\Workspace\java\scrape_indeed\web_dev_part_1...
# 29692  C:\Workspace\java\scrape_indeed\web_dev_part_1...
#
#                                              Occupations  \
# 91     Sr. Database Administrator/Data Analyst;Sr. Da...
# 163    Used Truck Sales;Benefit Support Specialist / ...
# 322    CLUB COORDINATOR/EVENT COORDINATOR;SUBSTITUTE ...
# 357    City Planner II & Development Review Administr...
# 498    Business Services Representative - Receptionis...
# ...                                                  ...
# 29530  Web designer / developer;Web designer / UI dev...
# 29609  Web Developer/PHP Developer/Perl Developer /Py...
# 29648  Sr. Web/UI Developer;Sr. Web/UI Developer;Sr. ...
# 29661  Web Developer/Designer;Product Developer/Autho...
# 29692  Web/UI Developer;Web/UI Developer;Web/UI Devel...
#
#                                                   Resume  \
# 91     Sr. Database Administrator/Data Analyst Sr. <s...
# 163    Used Truck Sales Used Truck Sales Used Truck S...
# 322    CLUB COORDINATOR/EVENT COORDINATOR CLUB COORDI...
# 357    City Planner II & Development Review Administr...
# 498    Business Services Representative - Receptionis...
# ...                                                  ...
# 29530  Web designer / developer <span class="hl">Web<...
# 29609  Web Developer/PHP Developer/Perl Developer /Py...
# 29648  Sr. Web/UI Developer Sr. <span class="hl">Web<...
# 29661  Web Developer/Designer <span class="hl">Web</s...
# 29692  Web/UI Developer <span class="hl">Web</span>/U...
#
#                                                   Labels  \
# 91               Database_Administrator\nProject_manager
# 163                               Database_Administrator
# 322
# 357
# 498
# ...                                                  ...
# 29530  Web_Developer\nSoftware_Developer\nFront_End_D...
# 29609  Web_Developer\nPython_Developer\nSoftware_Deve...
# 29648  Web_Developer\nSoftware_Developer\nFront_End_D...
# 29661                  Web_Developer\nSoftware_Developer
# 29692  Web_Developer\nSoftware_Developer\nFront_End_D...
#
#       Normalized_Occupation                                Preprocessed_Resume
# 91                           sr. database administrator/data analyst sr. da...
# 163                          used truck sales used truck sales used truck s...
# 322                          club coordinator/event coordinator club coordi...
# 357                          city planner ii development review administrat...
# 498                          business services representative - receptionis...
# ...                     ...                                                ...
# 29530                        web designer / developer web designer / develo...
# 29609                        web developer/php developer/perl developer /py...
# 29648                        sr. web/ui developer sr. web /ui developer sr....
# 29661                        web developer/designer web developer /designer...
# 29692                        web/ui developer web /ui developer web/ui deve...
#
# [648 rows x 6 columns]

# %%
pd.set_option('display.max_colwidth', 1000)
resume_data[['Resume', 'Preprocessed_Resume']]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Resume  \
# 0      Database Administrator <span class="hl">Database</span> <span class="hl">Administrator</span> Database Administrator - Family Private Care LLC Lawrenceville, GA A self-motivated Production SQL Server Database Administrator who possesses  strong analytical and problem solving skills. My experience includes SQL Server  2005, 2008 and 2012, 2014, SSIS, as well as clustering, mirroring, and high  availability solutions in OLTP environments. I am proficient in database backup,  recovery, performance tuning, maintenance tasks, security, and consolidation.  I am confident that I would make a beneficial addition to any company. Over the  course of my career thus far, I have designed databases to fit a variety of needs,  successfully ensured the security of those databases, problem-solved in order to meet  both back-end and front-end needs, installed and tested new versions database  management systems, customized and installed applications and meticulously  monitored performance for the sm...
# 1      Database Administrator <span class="hl">Database</span> <span class="hl">Administrator</span> sql server database administrator Houston, TX DATABASE ADMINISTRATOR  Over five years of experience in database management systems administration, expert at developing and maintaining database, with strong background of working on high-end servers. I would like to establish a fulfilling, proactive career and assume every increasing responsibility in the course of time. Work Experience Database Administrator Intercontinental Registry - Lagos, GU December 2008 to August 2011 Responsibilities  Key responsibilities.  Planning, Development:  Involved in analyzing business requirements, developing and designing data models,   Provided and designed DB tools to assist in the database management, transactions and processing environments.   Assessed and executed implementing of new technologies.   Worked in coordination with company developers and project managers.   Developed training programs ...
# 2      Oracle Database Administrator Oracle <span class="hl">Database</span> <span class="hl">Administrator</span> Oracle Database Administrator - Cognizant hyderabad Carrier Objective:  To Obtain a Oracle DBA Position in a progressive Company Where I Can Utilise and Enhance my Experience and Knowledge in Constituting Effectively to the Success of the Organization, and also to Improve my Further Technical and Professional Skills.  Profile Summary:   Over 4+ years of Experience as Architecture.   Experienced in Installation and Maintaining Highly Critical Databases in any Operational mode on Unix/Linux, Sun Solaris.   Experienced in 10g, 11g, 12c databases.   Responsible for installing Oracle 11g and 12c in Single Node & Multi node's Configure host and listener.   Experienced in Creating Users, Roles and Profiles, Assigning Roles and Profiles to Users.   Experience on Data Guard setup 10g/11g/12c.   Expertise in Managing and monitoring Database Storage Structures, Data Files Space, ...
# 3      Amazon Redshift Administrator and ETL Developer, Business Intelligence Amazon Redshift <span class="hl">Administrator</span> and ETL Developer, Business Intelligence ETL Developer and Database Administrator Plantation, FL To work as database administrator, implementing this role appropriately and effectively in the organizations Authorized to work in the US for any employer Work Experience Amazon Redshift Administrator and ETL Developer, Business Intelligence MSP Recovery - Fort Lauderdale, FL February 2018 to Present Maintain multiple database environments (Redshift, RDS) in AWS.  User management and group in Redshift.  Design and Developed ETL jobs to extract data from RDS and load it in Redshift Matillion ETL and python script).  Experience working within the AWS Big Data Ecosystem (S3, RDS, and Redshift).     Expertise in development of various reports and prepare the data for the utilization with tableau.  Expertise Query Tuning and Performance optimization and Implementing Wo...
# 4      Scrum Master Scrum Master Scrum Master Richmond, VA Work Experience Scrum Master Quest Technologies - Washington, DC October 2015 to April 2019 Responsibilities:  Organize and facilitate Scrum ceremonies and backlog refinement under minimal supervision   Champion Agile software development best practices, acting as a coach to the Scrum teams   Support the Product Owner in grooming and maintaining the product backlog   Track and communicate team status and progress via burnup and burndown charts, as well as other information radiators, to the team, management, and stakeholders ¬ ensuring it accurately reflects current state   Take responsibility for managing dependencies between the Scrum team and others, collaborating within the Scrum Master network ¬ especially with regard to items necessary for product release   Demonstrate sense of urgency and responsiveness to complete work and solve problems, with a strong drive to persevere when faced with ambiguity   Proactively remove...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 29775  ServiceNow Developer ServiceNow <span class="hl">Developer</span> ServiceNow Developer - Vertex Pharmaceuticals Boston, MA  8 Years of IT experience in Software Design, Development, Analysis, Testing and Implementation   End to End Development and Customization of ITSM and Non ITSM applications per ITIL.   A ServiceNow Technology Analyst with experience on implementing end-to-end Service Catalog, Incident Management, Configuration & Asset Management, Change Management and Release Management with extensive knowledge on Content Management System.   Wrote business rules to avoid empty configuration items to be inserted into CMDB after discovery tool runs a scheduled job   CMDB/Asset form re-engineering, role based approach, enhancements.   Worked with Application Owners to restructure CMDB based on Company's Architecture.   Gathering requirements and converting BRD's into technical requirements. Created design patterns & implementation plans for ServiceNow enhancements.   Desi...
# 29776  Android Developer Android <span class="hl">Developer</span> Android Developer - HCL America/Samsung Keller, TX Work Experience Android Developer HCL America/Samsung September 2018 to Present Berkley Heights, NJ    Responsibilities:   Working in team of Android Developers, team lead and User interface design team on Samsung applications. Have to make sure the applications are developed in compliance with company global requirements. Follow company security and information exchange policies while implementing solutions. Have to develop app for different carriers.   Working on UI and backend of the applications using XML and Java.   Using Gerrit and Perforce as version control management tool.   Flash devices using binaries and Odin tool. Android Developer SleepScore Labs - Carlsbad, CA March 2017 to August 2018 SleepScore App    Sleepscore has few products. Working on its Android app. It's into Agile environment.There is a team of 2 other Android developers, we have co-ordinate w...
# 29777  UI Developer UI <span class="hl">Developer</span> UI Developer - Cotiviti Health Care Blue Bell, PA  Around 6 years of experience in the Web Applications Development using HTML 4.01/5, CSS (2/3), XHTML, JavaScript, Angular JS,JQuery, AJAX, XML and JSON.   Experience with full software development life-cycle, architecting scalable platforms, object oriented programming, and agile methodologies   Strong experience with JQuery, JQuery plugins (Validator, Drag and Drop, AutoComplete), AJAX, Dynamic HTML (DHTML) and JSON.   Experience with Responsive Web Design, JSON, AJAX, Angular JS, React JS and Twitter Bootstrap.   Experience in Graphic and User Experience Design and Transforming Web/Graphic Designers static prototypes into hand-coded HTML, specifically emphasizing accuracy and efficiency & adhering to W3C-established web standards with respect to maintaining cross-browser/cross-platform compatibility and delivering final page templates, including optimized images.   Experienc...
# 29778                                                                                                                                                Web Developer <span class="hl">Web</span> <span class="hl">Developer</span> Los Angeles, CA Work Experience Web Developer self employed September 2013 to July 2019  Creating design for basic portfolio to company website    Creating websites using standard HTML/CSS   Have an experience with UX/UI   Experience with typography and text optimization for better link working on a website   Basic knowledge of SEO   Basic experience of JS, JQ, PHP and database systems such as SQL/MySQL   Basic knowledge of website elements optimization for best loading speed   Experience working with Photoshop and photo correction   Basic knowledge and experience to make a main photo for website (as example for actor portfolio website)   ability to find the right information to improve job skills Education Associate Skills Javascript, PHP, Front End, Wordpress
# 29779  Sr. Software Engineer Sr. Software Engineer Sr. Software Engineer - The Krazy Coupon Lady Colorado Springs, CO Authorized to work in the US for any employer Work Experience Sr. Software Engineer The Krazy Coupon Lady - Colorado Springs, CO April 2019 to Present  Lead migration from a headless WordPress onto Graph CMS to allow marketing flexibility and remove hardcoded features from current system.   Manage production team and interface with interdepartmental leadership to ensure a quality reflection of business logic in code bases in a way that encourages CI/CD.   Provide insight and experience to rebuild the primary web product using React, Apollo, Next.js, GraphQL, and AWS Lambda Servers.   Reverse engineer, debug, and document deployment processes and features for everything from the primary product to their Salesforce integrations. DevOps Manager The Colorado Springs Gazette - Colorado Springs, CO January 2019 to April 2019  Oversee the creation of team deliverables includ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Preprocessed_Resume
# 0      database administrator database administrator database administrator - family private care llc lawrenceville ga self-motivated production sql server database administrator possesses strong analytical problem solving skills . experience includes sql server 2005 2008 2012 2014 ssis well clustering mirroring high availability solutions oltp environments . proficient database backup recovery performance tuning maintenance tasks security consolidation . confident would make beneficial addition company . course career thus far designed databases fit variety needs successfully ensured security databases problem-solved order meet back-end front-end needs installed tested new versions database management systems customized installed applications meticulously monitored performance smoothest front-end experience possible . 5 6 years working databases . work experience database administrator family private care llc - roswell ga april 2017 present confirm backups made successfully saved secure ...
# 1      database administrator database administrator sql server database administrator houston tx database administrator five years experience database management systems administration expert developing maintaining database strong background working high-end servers . would like establish fulfilling proactive career assume every increasing responsibility course time . work experience database administrator intercontinental registry - lagos gu december 2008 august 2011 responsibilities key responsibilities . planning development involved analyzing business requirements developing designing data models provided designed db tools assist database management transactions processing environments . assessed executed implementing new technologies . worked coordination company developers project managers . developed training programs trained technical support applications personnel utilize on-line databases environment process . technical support monitored performance capacity provide resolutions...
# 2      oracle database administrator oracle database administrator oracle database administrator - cognizant hyderabad carrier objective obtain oracle dba position progressive company utilise enhance experience knowledge constituting effectively success organization also improve technical professional skills . profile summary 4+ years experience architecture . experienced installation maintaining highly critical databases operational mode unix/linux sun solaris . experienced 10g 11g 12c databases . responsible installing oracle 11g 12c single node multi node configure host listener . experienced creating users roles profiles assigning roles profiles users . experience data guard setup 10g/11g/12c . expertise managing monitoring database storage structures data files space resizing adding new data files . maintaining cold hot logical rman backups databases . performing logical backups using export utility restoring specific object schema using import utility . monitoring performing daily i...
# 3      amazon redshift administrator etl developer business intelligence amazon redshift administrator etl developer business intelligence etl developer database administrator plantation fl work database administrator implementing role appropriately effectively organizations authorized work us employer work experience amazon redshift administrator etl developer business intelligence msp recovery - fort lauderdale fl february 2018 present maintain multiple database environments redshift rds aws . user management group redshift . design developed etl jobs extract data rds load redshift matillion etl python script . experience working within aws big data ecosystem s3 rds redshift . expertise development various reports prepare data utilization tableau . expertise query tuning performance optimization implementing work load management . managing amazon redshift snapshots using console . database administrator ceaaces - quito provincia de pichincha november 2014 december 2015 quito ecuador des...
# 4      scrum master scrum master scrum master richmond va work experience scrum master quest technologies - washington dc october 2015 april 2019 responsibilities organize facilitate scrum ceremonies backlog refinement minimal supervision champion agile software development best practices acting coach scrum teams support product owner grooming maintaining product backlog track communicate team status progress via burnup burndown charts well information radiators team management stakeholders ensuring accurately reflects current state take responsibility managing dependencies scrum team others collaborating within scrum master network especially regard items necessary product release demonstrate sense urgency responsiveness complete work solve problems strong drive persevere faced ambiguity proactively remove escalate roadblocks allow team progress maintains relevant metrics help team monitor performance encourages continual improvement engineering practices improve code quality delivery co...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 29775  servicenow developer servicenow developer servicenow developer - vertex pharmaceuticals boston 8 years experience software design development analysis testing implementation end end development customization itsm non itsm applications per itil . servicenow technology analyst experience implementing end-to-end service catalog incident management configuration asset management change management release management extensive knowledge content management system . wrote business rules avoid empty configuration items inserted cmdb discovery tool runs scheduled job cmdb/asset form re-engineering role based approach enhancements . worked application owners restructure cmdb based company architecture . gathering requirements converting brd technical requirements . created design patterns implementation plans servicenow enhancements . design engineer solutions leveraging appropriate components offered service-now answer needs business workflows ticketing itsm requirements . developing javascr...
# 29776  android developer android developer android developer - hcl america/samsung keller tx work experience android developer hcl america/samsung september 2018 present berkley heights nj responsibilities working team android developers team lead user interface design team samsung applications . make sure applications developed compliance company global requirements . follow company security information exchange policies implementing solutions . develop app different carriers . working ui backend applications using xml java . using gerrit perforce version control management tool . flash devices using binaries odin tool . android developer sleepscore labs - carlsbad ca march 2017 august 2018 sleepscore app sleepscore products . working android app . agile environment.there team 2 android developers co-ordinate . coordinate designers web developers project manager qa accomplish features app . responsibilities worked frontend using xml . used java backend . sqlite shared preferences store u...
# 29777  ui developer ui developer ui developer - cotiviti health care blue bell pa around 6 years experience web applications development using html 4.01/5 css 2/3 xhtml javascript angular js jquery ajax xml json . experience full software development life-cycle architecting scalable platforms object oriented programming agile methodologies strong experience jquery jquery plugins validator drag drop autocomplete ajax dynamic html dhtml json . experience responsive web design json ajax angular js react js twitter bootstrap . experience graphic user experience design transforming web/graphic designers static prototypes hand-coded html specifically emphasizing accuracy efficiency adhering w3c-established web standards respect maintaining cross-browser/cross-platform compatibility delivering final page templates including optimized images . experience applications using ajax object oriented oo javascript json jsonp xml . experience working mvc architecture also using version control svn experi...
# 29778                                                                                                                                                                                                                                                                                                                                               web developer web developer los angeles ca work experience web developer self employed september 2013 july 2019 creating design basic portfolio company website creating websites using standard html/css experience ux/ui experience typography text optimization better link working website basic knowledge seo basic experience js jq php database systems sql/mysql basic knowledge website elements optimization best loading speed experience working photoshop photo correction basic knowledge experience make main photo website example actor portfolio website ability find right information improve job skills education associate skills javascript php front end wordpress
# 29779  sr. software engineer sr. software engineer sr. software engineer - krazy coupon lady colorado springs co authorized work us employer work experience sr. software engineer krazy coupon lady - colorado springs co april 2019 present lead migration headless wordpress onto graph cms allow marketing flexibility remove hardcoded features current system . manage production team interface interdepartmental leadership ensure quality reflection business logic code bases way encourages ci/cd . provide insight experience rebuild primary web product using react apollo next.js graphql aws lambda servers . reverse engineer debug document deployment processes features everything primary product salesforce integrations . devops manager colorado springs gazette - colorado springs co january 2019 april 2019 oversee creation team deliverables including code development architecture documentation qa high-quality standards . develop drive strategic vision continuous improvement roadmap optimizes organiz...
#
# [29780 rows x 2 columns]

# %%
resume_data.isnull().sum()
# Out:
# ID                       0
# Occupations              0
# Resume                   0
# Labels                   0
# Normalized_Occupation    0
# Preprocessed_Resume      0
# dtype: int64

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29780 entries, 0 to 29779
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     29780 non-null  object
#  1   Occupations            29780 non-null  object
#  2   Resume                 29780 non-null  object
#  3   Labels                 29780 non-null  object
#  4   Normalized_Occupation  29780 non-null  object
#  5   Preprocessed_Resume    29780 non-null  object
# dtypes: object(6)
# memory usage: 1.4+ MB
